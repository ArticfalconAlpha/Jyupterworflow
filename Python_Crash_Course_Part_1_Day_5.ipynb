# %%
print("Helo")
# Out:
# Helo

# %%
V_name='Sunny'
print("My name is {}".format(V_name))
# Out:
# My name is Sunny

# %%
V_age = 23
print(f"Age is {V_age}")
# Out:
# Age is 23

# %%
V_list = [1,'a',3,4]
print(V_list[1])
# Out:
# a

# %%
## appending in a list
V_veggies = ['Tomato' , 'Potato']
V_veggies.append('Onion')
print(V_veggies)
# Out:
# ['Tomato', 'Potato', 'Onion']

# %%
##Nested list
V_Nested_List = [1,2,[100,200]]
print(V_Nested_List[2][1])
## Appending in a nested list
V_Nested_List.append([2]1)
print(V_Nested_List)
# Out:
#   File "<command-380517219554470>", line 5
#     V_Nested_List.append([2]1)
#                             ^
# SyntaxError: invalid syntax

# %%
##Dictionary
V_Dict = {'Key':'Value','Key1':'Value1'}
print(V_Dict)
# Out:
# {'Key': 'Value', 'Key1': 'Value1'}
# Value

# %%
print(V_Dict['Key'])
# Out:
# Value

# %%
## Tuple  -- cannot add values
V_Tuple = (1,2,3)
print(V_Tuple[0])
# Out:
# 1

# %%
##SET will have only distinct values
V_Set ={1,2,3,3,3,4,2,343,2,}
print(V_Set)
# Out:
# {1, 2, 3, 4, 343}
